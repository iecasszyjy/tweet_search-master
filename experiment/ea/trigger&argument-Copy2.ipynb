# %%
from datetime import datetime,timedelta
from nltk.corpus import stopwords
import pandas as pd
import spacy

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from collections import defaultdict
import itertools

# %%
list_stopWords=list(set(stopwords.words('english')))

# %%
nlp = spacy.load('en_core_web_md')

# %%
df_demo = pd.read_csv('demo.csv',index_col=0)

# %%
df_demo.head()
# Out:
#                      class      date  \
# 0  Disasters and accidents  2017/9/1
# 1      Health and medicine  2017/9/1
# 2  International relations  2017/9/1
# 3            Law and crime  2017/9/1
# 4   Politics and elections  2017/9/1
#
#                                          description  \
# 0  Hurricane Irma, now a Category 2 hurricane wit...
# 1  Researchers report, in the Environmental Scien...
# 2  South Korean President Moon Jae-in and U.S. Pr...
# 3  United States federal judge Richard Posner has...
# 4  The Labour Party, led by Jacinda Ardern, surge...
#
#                                                title
# 0                     2017 Atlantic hurricane season
# 1                                        Great Lakes
# 2                South Korea鈥揢nited States relations
# 3  United States Court of Appeals for the Seventh...
# 4                 New Zealand general election, 2017

# %%
def class_code(type_str):
    type_str = type_str.lower()
    if 'armed' in type_str or 'attack' in type_str or 'conflict' in type_str:
        return 1
    elif 'disaster' in type_str or 'accident' in type_str:
        return 2
    elif 'law' in type_str or 'crime' in type_str:
        return 3
    elif 'politic' in type_str or 'election' in type_str:
        return 4
    elif 'international' in type_str or 'relation' in type_str:
        return 5
    elif 'science' in type_str or 'technology' in type_str:
        return 6
    elif 'business' in type_str or 'econom' in type_str:
        return 7
    elif 'art' in type_str or 'culture' in type_str:
        return 8
    elif 'sport' in type_str:
        return 9
    elif 'health' in type_str or 'environment' in type_str:
        return 10
    else:
        return 0

# %%
df_demo['class_code'] = df_demo['class'].apply(class_code)

# %%
df_demo.head()
# Out:
#                      class      date  \
# 0  Disasters and accidents  2017/9/1
# 1      Health and medicine  2017/9/1
# 2  International relations  2017/9/1
# 3            Law and crime  2017/9/1
# 4   Politics and elections  2017/9/1
#
#                                          description  \
# 0  Hurricane Irma, now a Category 2 hurricane wit...
# 1  Researchers report, in the Environmental Scien...
# 2  South Korean President Moon Jae-in and U.S. Pr...
# 3  United States federal judge Richard Posner has...
# 4  The Labour Party, led by Jacinda Ardern, surge...
#
#                                                title  class_code
# 0                     2017 Atlantic hurricane season           2
# 1                                        Great Lakes          10
# 2                South Korea鈥揢nited States relations           5
# 3  United States Court of Appeals for the Seventh...           3
# 4                 New Zealand general election, 2017           4

# %%
def description_clean(description):
    description = description.split('. (')[0]+'.'
    return description

# %%
df_demo['des_clean'] = df_demo['description'].apply(description_clean)

# %%
def efitf(X):
    count = CountVectorizer(stop_words='english')
    X_train_count = count.fit_transform(X)
    tfidf = TfidfTransformer(use_idf=True,smooth_idf=True,sublinear_tf=True)
    X_train_tfidf = tfidf.fit_transform(X_train_count)
    tf_feature_names = count.get_feature_names()
    X_train_tfidf = [list(i) for i in list(X_train_tfidf.toarray())]
    EFITF = defaultdict(dict)
    for Type,values in enumerate(X_train_tfidf):
        for index,value in enumerate(values):
            if value > 0.0:
                EFITF[Type].update({tf_feature_names[index]:value}) 
    return EFITF

# %%
X = []

# %%
X = df_demo['des_clean'].tolist()

# %%
EFITF = efitf(X)

# %%
def class_similarity(class_text,span):
    return nlp(class_text).similarity(nlp(span))

# %%
def get_query(doc,class_text,doc_index,doc_date):
    date_1 = (datetime.strptime(doc_date,'%Y/%m/%d')+timedelta(days=1)).strftime('%Y-%m-%d')
    date_0 = datetime.strptime(doc_date,'%Y/%m/%d').strftime('%Y-%m-%d')
    doc = nlp(doc)
    kws = []
    for i in doc.ents:
        kws.append(i.text)
    triggers = []
    for token in doc:
        if not token.is_stop and token.tag_.startswith('V'):
            if token.text.lower() in EFITF[doc_index].keys():
                triggers.append((token.text,token.tag_,str(class_similarity(class_text,token.text)+EFITF[doc_index][token.text.lower()])))
    triggers = sorted(triggers,key=lambda x:x[2],reverse=True)[:3]
    for i in triggers:
        kws.append(i[0])
    noun_chunks = []
    for i in doc.noun_chunks:
        noun_chunks.append((i.text,str(class_similarity(class_text,i.text))))
    kws.append(sorted(noun_chunks,key=lambda x:x[1],reverse=True)[0][0].split(' ')[-1])
    kws = [w for w in kws if not w in list_stopWords]
    kws = list(set(kws))
    query = [i for i in itertools.combinations(kws,2)]
    query = ['"'+i[0]+'"'+' '+'"'+i[1]+'"'+' '+'until:'+date_0 for i in query]+['"'+i[0]+'"'+' '+'"'+i[1]+'"'+' '+'until:'+date_1 for i in query]
    return query

# %%
for event in df_demo.iterrows():
    doc_index = event[0]
    doc_date = event[1]['date']
    doc_class = event[1]['class']
    doc_title = event[1]['title']
    doc = event[1]['des_clean']
    class_text = doc_class.replace('and','')
    query = get_query(doc,class_text,doc_index,doc_date)
    print(len(query),'\n',query)
# Out:
# 132
#  ['"this weekend" "strengthening" until:2017-09-01', '"this weekend" "the Leeward Islands" until:2017-09-01', '"this weekend" "175 kilometers per hour" until:2017-09-01', '"this weekend" "expected" until:2017-09-01', '"this weekend" "danger" until:2017-09-01', '"this weekend" "Hurricane Irma" until:2017-09-01', '"this weekend" "Category 2" until:2017-09-01', '"this weekend" "Caribbean" until:2017-09-01', '"this weekend" "next Thursday" until:2017-09-01', '"this weekend" "increasing" until:2017-09-01', '"this weekend" "110 miles per hour" until:2017-09-01', '"strengthening" "the Leeward Islands" until:2017-09-01', '"strengthening" "175 kilometers per hour" until:2017-09-01', '"strengthening" "expected" until:2017-09-01', '"strengthening" "danger" until:2017-09-01', '"strengthening" "Hurricane Irma" until:2017-09-01', '"strengthening" "Category 2" until:2017-09-01', '"strengthening" "Caribbean" until:2017-09-01', '"strengthening" "next Thursday" until:2017-09-01', '"strengthening" "increasing" until:2017-09-01', '"strengthening" "110 miles per hour" until:2017-09-01', '"the Leeward Islands" "175 kilometers per hour" until:2017-09-01', '"the Leeward Islands" "expected" until:2017-09-01', '"the Leeward Islands" "danger" until:2017-09-01', '"the Leeward Islands" "Hurricane Irma" until:2017-09-01', '"the Leeward Islands" "Category 2" until:2017-09-01', '"the Leeward Islands" "Caribbean" until:2017-09-01', '"the Leeward Islands" "next Thursday" until:2017-09-01', '"the Leeward Islands" "increasing" until:2017-09-01', '"the Leeward Islands" "110 miles per hour" until:2017-09-01', '"175 kilometers per hour" "expected" until:2017-09-01', '"175 kilometers per hour" "danger" until:2017-09-01', '"175 kilometers per hour" "Hurricane Irma" until:2017-09-01', '"175 kilometers per hour" "Category 2" until:2017-09-01', '"175 kilometers per hour" "Caribbean" until:2017-09-01', '"175 kilometers per hour" "next Thursday" until:2017-09-01', '"175 kilometers per hour" "increasing" until:2017-09-01', '"175 kilometers per hour" "110 miles per hour" until:2017-09-01', '"expected" "danger" until:2017-09-01', '"expected" "Hurricane Irma" until:2017-09-01', '"expected" "Category 2" until:2017-09-01', '"expected" "Caribbean" until:2017-09-01', '"expected" "next Thursday" until:2017-09-01', '"expected" "increasing" until:2017-09-01', '"expected" "110 miles per hour" until:2017-09-01', '"danger" "Hurricane Irma" until:2017-09-01', '"danger" "Category 2" until:2017-09-01', '"danger" "Caribbean" until:2017-09-01', '"danger" "next Thursday" until:2017-09-01', '"danger" "increasing" until:2017-09-01', '"danger" "110 miles per hour" until:2017-09-01', '"Hurricane Irma" "Category 2" until:2017-09-01', '"Hurricane Irma" "Caribbean" until:2017-09-01', '"Hurricane Irma" "next Thursday" until:2017-09-01', '"Hurricane Irma" "increasing" until:2017-09-01', '"Hurricane Irma" "110 miles per hour" until:2017-09-01', '"Category 2" "Caribbean" until:2017-09-01', '"Category 2" "next Thursday" until:2017-09-01', '"Category 2" "increasing" until:2017-09-01', '"Category 2" "110 miles per hour" until:2017-09-01', '"Caribbean" "next Thursday" until:2017-09-01', '"Caribbean" "increasing" until:2017-09-01', '"Caribbean" "110 miles per hour" until:2017-09-01', '"next Thursday" "increasing" until:2017-09-01', '"next Thursday" "110 miles per hour" until:2017-09-01', '"increasing" "110 miles per hour" until:2017-09-01', '"this weekend" "strengthening" until:2017-09-02', '"this weekend" "the Leeward Islands" until:2017-09-02', '"this weekend" "175 kilometers per hour" until:2017-09-02', '"this weekend" "expected" until:2017-09-02', '"this weekend" "danger" until:2017-09-02', '"this weekend" "Hurricane Irma" until:2017-09-02', '"this weekend" "Category 2" until:2017-09-02', '"this weekend" "Caribbean" until:2017-09-02', '"this weekend" "next Thursday" until:2017-09-02', '"this weekend" "increasing" until:2017-09-02', '"this weekend" "110 miles per hour" until:2017-09-02', '"strengthening" ...
# 90
#  ['"Ontario" "introduced" until:2017-09-01', '"Ontario" "journal" until:2017-09-01', '"Ontario" "the Niagara River" until:2017-09-01', '"Ontario" "the Environmental Science & Technology" until:2017-09-01', '"Ontario" "10" until:2017-09-01', '"Ontario" "Lakes Erie" until:2017-09-01', '"Ontario" "include" until:2017-09-01', '"Ontario" "report" until:2017-09-01', '"Ontario" "the Great Lakes" until:2017-09-01', '"introduced" "journal" until:2017-09-01', '"introduced" "the Niagara River" until:2017-09-01', '"introduced" "the Environmental Science & Technology" until:2017-09-01', '"introduced" "10" until:2017-09-01', '"introduced" "Lakes Erie" until:2017-09-01', '"introduced" "include" until:2017-09-01', '"introduced" "report" until:2017-09-01', '"introduced" "the Great Lakes" until:2017-09-01', '"journal" "the Niagara River" until:2017-09-01', '"journal" "the Environmental Science & Technology" until:2017-09-01', '"journal" "10" until:2017-09-01', '"journal" "Lakes Erie" until:2017-09-01', '"journal" "include" until:2017-09-01', '"journal" "report" until:2017-09-01', '"journal" "the Great Lakes" until:2017-09-01', '"the Niagara River" "the Environmental Science & Technology" until:2017-09-01', '"the Niagara River" "10" until:2017-09-01', '"the Niagara River" "Lakes Erie" until:2017-09-01', '"the Niagara River" "include" until:2017-09-01', '"the Niagara River" "report" until:2017-09-01', '"the Niagara River" "the Great Lakes" until:2017-09-01', '"the Environmental Science & Technology" "10" until:2017-09-01', '"the Environmental Science & Technology" "Lakes Erie" until:2017-09-01', '"the Environmental Science & Technology" "include" until:2017-09-01', '"the Environmental Science & Technology" "report" until:2017-09-01', '"the Environmental Science & Technology" "the Great Lakes" until:2017-09-01', '"10" "Lakes Erie" until:2017-09-01', '"10" "include" until:2017-09-01', '"10" "report" until:2017-09-01', '"10" "the Great Lakes" until:2017-09-01', '"Lakes Erie" "include" until:2017-09-01', '"Lakes Erie" "report" until:2017-09-01', '"Lakes Erie" "the Great Lakes" until:2017-09-01', '"include" "report" until:2017-09-01', '"include" "the Great Lakes" until:2017-09-01', '"report" "the Great Lakes" until:2017-09-01', '"Ontario" "introduced" until:2017-09-02', '"Ontario" "journal" until:2017-09-02', '"Ontario" "the Niagara River" until:2017-09-02', '"Ontario" "the Environmental Science & Technology" until:2017-09-02', '"Ontario" "10" until:2017-09-02', '"Ontario" "Lakes Erie" until:2017-09-02', '"Ontario" "include" until:2017-09-02', '"Ontario" "report" until:2017-09-02', '"Ontario" "the Great Lakes" until:2017-09-02', '"introduced" "journal" until:2017-09-02', '"introduced" "the Niagara River" until:2017-09-02', '"introduced" "the Environmental Science & Technology" until:2017-09-02', '"introduced" "10" until:2017-09-02', '"introduced" "Lakes Erie" until:2017-09-02', '"introduced" "include" until:2017-09-02', '"introduced" "report" until:2017-09-02', '"introduced" "the Great Lakes" until:2017-09-02', '"journal" "the Niagara River" until:2017-09-02', '"journal" "the Environmental Science & Technology" until:2017-09-02', '"journal" "10" until:2017-09-02', '"journal" "Lakes Erie" until:2017-09-02', '"journal" "include" until:2017-09-02', '"journal" "report" until:2017-09-02', '"journal" "the Great Lakes" until:2017-09-02', '"the Niagara River" "the Environmental Science & Technology" until:2017-09-02', '"the Niagara River" "10" until:2017-09-02', '"the Niagara River" "Lakes Erie" until:2017-09-02', '"the Niagara River" "include" until:2017-09-02', '"the Niagara River" "report" until:2017-09-02', '"the Niagara River" "the Great Lakes" until:2017-09-02', '"the Environmental Science & Technology" "10" until:2017-09-02', '"the Environmental Science & Technology" "Lakes Erie" until:2017-09-02', '"the Environmental Science & Technology" "include" until:2017-09-02', '"the Environmental Science & Technology" "report" until:2017-09-02', '"the Environme ...
# 90
#  ['"South Korea\'s" "development" until:2017-09-01', '"South Korea\'s" "South Korea" until:2017-09-01', '"South Korea\'s" "caps" until:2017-09-01', '"South Korea\'s" "U.S." until:2017-09-01', '"South Korea\'s" "Moon Jae" until:2017-09-01', '"South Korea\'s" "revise" until:2017-09-01', '"South Korea\'s" "South Korean" until:2017-09-01', '"South Korea\'s" "Donald Trump" until:2017-09-01', '"South Korea\'s" "agree" until:2017-09-01', '"development" "South Korea" until:2017-09-01', '"development" "caps" until:2017-09-01', '"development" "U.S." until:2017-09-01', '"development" "Moon Jae" until:2017-09-01', '"development" "revise" until:2017-09-01', '"development" "South Korean" until:2017-09-01', '"development" "Donald Trump" until:2017-09-01', '"development" "agree" until:2017-09-01', '"South Korea" "caps" until:2017-09-01', '"South Korea" "U.S." until:2017-09-01', '"South Korea" "Moon Jae" until:2017-09-01', '"South Korea" "revise" until:2017-09-01', '"South Korea" "South Korean" until:2017-09-01', '"South Korea" "Donald Trump" until:2017-09-01', '"South Korea" "agree" until:2017-09-01', '"caps" "U.S." until:2017-09-01', '"caps" "Moon Jae" until:2017-09-01', '"caps" "revise" until:2017-09-01', '"caps" "South Korean" until:2017-09-01', '"caps" "Donald Trump" until:2017-09-01', '"caps" "agree" until:2017-09-01', '"U.S." "Moon Jae" until:2017-09-01', '"U.S." "revise" until:2017-09-01', '"U.S." "South Korean" until:2017-09-01', '"U.S." "Donald Trump" until:2017-09-01', '"U.S." "agree" until:2017-09-01', '"Moon Jae" "revise" until:2017-09-01', '"Moon Jae" "South Korean" until:2017-09-01', '"Moon Jae" "Donald Trump" until:2017-09-01', '"Moon Jae" "agree" until:2017-09-01', '"revise" "South Korean" until:2017-09-01', '"revise" "Donald Trump" until:2017-09-01', '"revise" "agree" until:2017-09-01', '"South Korean" "Donald Trump" until:2017-09-01', '"South Korean" "agree" until:2017-09-01', '"Donald Trump" "agree" until:2017-09-01', '"South Korea\'s" "development" until:2017-09-02', '"South Korea\'s" "South Korea" until:2017-09-02', '"South Korea\'s" "caps" until:2017-09-02', '"South Korea\'s" "U.S." until:2017-09-02', '"South Korea\'s" "Moon Jae" until:2017-09-02', '"South Korea\'s" "revise" until:2017-09-02', '"South Korea\'s" "South Korean" until:2017-09-02', '"South Korea\'s" "Donald Trump" until:2017-09-02', '"South Korea\'s" "agree" until:2017-09-02', '"development" "South Korea" until:2017-09-02', '"development" "caps" until:2017-09-02', '"development" "U.S." until:2017-09-02', '"development" "Moon Jae" until:2017-09-02', '"development" "revise" until:2017-09-02', '"development" "South Korean" until:2017-09-02', '"development" "Donald Trump" until:2017-09-02', '"development" "agree" until:2017-09-02', '"South Korea" "caps" until:2017-09-02', '"South Korea" "U.S." until:2017-09-02', '"South Korea" "Moon Jae" until:2017-09-02', '"South Korea" "revise" until:2017-09-02', '"South Korea" "South Korean" until:2017-09-02', '"South Korea" "Donald Trump" until:2017-09-02', '"South Korea" "agree" until:2017-09-02', '"caps" "U.S." until:2017-09-02', '"caps" "Moon Jae" until:2017-09-02', '"caps" "revise" until:2017-09-02', '"caps" "South Korean" until:2017-09-02', '"caps" "Donald Trump" until:2017-09-02', '"caps" "agree" until:2017-09-02', '"U.S." "Moon Jae" until:2017-09-02', '"U.S." "revise" until:2017-09-02', '"U.S." "South Korean" until:2017-09-02', '"U.S." "Donald Trump" until:2017-09-02', '"U.S." "agree" until:2017-09-02', '"Moon Jae" "revise" until:2017-09-02', '"Moon Jae" "South Korean" until:2017-09-02', '"Moon Jae" "Donald Trump" until:2017-09-02', '"Moon Jae" "agree" until:2017-09-02', '"revise" "South Korean" until:2017-09-02', '"revise" "Donald Trump" until:2017-09-02', '"revise" "agree" until:2017-09-02', '"South Korean" "Donald Trump" until:2017-09-02', '"South Korean" "agree" until:2017-09-02', '"Donald Trump" "agree" until:2017-09-02']
# 210
#  ['"Appointed" "written" until:2017-09-01', '"Appointed" "Richard Posner" until:2017-09-01', '"Appointed" "three decades" until:2017-09-01', '"Appointed" "Chicago" until:2017-09-01', '"Appointed" "7th" until:2017-09-01', '"Appointed" "headquartered" until:2017-09-01', '"Appointed" "Posner" until:2017-09-01', '"Appointed" "U.S. Circuit Court of Appeals" until:2017-09-01', '"Appointed" "Illinois" until:2017-09-01', '"Appointed" "bench.(AP" until:2017-09-01', '"Appointed" "United States" until:2017-09-01', '"Appointed" "Ronald Reagan" until:2017-09-01', '"Appointed" "1981" until:2017-09-01', '"Appointed" "more than 3,300" until:2017-09-01', '"written" "Richard Posner" until:2017-09-01', '"written" "three decades" until:2017-09-01', '"written" "Chicago" until:2017-09-01', '"written" "7th" until:2017-09-01', '"written" "headquartered" until:2017-09-01', '"written" "Posner" until:2017-09-01', '"written" "U.S. Circuit Court of Appeals" until:2017-09-01', '"written" "Illinois" until:2017-09-01', '"written" "bench.(AP" until:2017-09-01', '"written" "United States" until:2017-09-01', '"written" "Ronald Reagan" until:2017-09-01', '"written" "1981" until:2017-09-01', '"written" "more than 3,300" until:2017-09-01', '"Richard Posner" "three decades" until:2017-09-01', '"Richard Posner" "Chicago" until:2017-09-01', '"Richard Posner" "7th" until:2017-09-01', '"Richard Posner" "headquartered" until:2017-09-01', '"Richard Posner" "Posner" until:2017-09-01', '"Richard Posner" "U.S. Circuit Court of Appeals" until:2017-09-01', '"Richard Posner" "Illinois" until:2017-09-01', '"Richard Posner" "bench.(AP" until:2017-09-01', '"Richard Posner" "United States" until:2017-09-01', '"Richard Posner" "Ronald Reagan" until:2017-09-01', '"Richard Posner" "1981" until:2017-09-01', '"Richard Posner" "more than 3,300" until:2017-09-01', '"three decades" "Chicago" until:2017-09-01', '"three decades" "7th" until:2017-09-01', '"three decades" "headquartered" until:2017-09-01', '"three decades" "Posner" until:2017-09-01', '"three decades" "U.S. Circuit Court of Appeals" until:2017-09-01', '"three decades" "Illinois" until:2017-09-01', '"three decades" "bench.(AP" until:2017-09-01', '"three decades" "United States" until:2017-09-01', '"three decades" "Ronald Reagan" until:2017-09-01', '"three decades" "1981" until:2017-09-01', '"three decades" "more than 3,300" until:2017-09-01', '"Chicago" "7th" until:2017-09-01', '"Chicago" "headquartered" until:2017-09-01', '"Chicago" "Posner" until:2017-09-01', '"Chicago" "U.S. Circuit Court of Appeals" until:2017-09-01', '"Chicago" "Illinois" until:2017-09-01', '"Chicago" "bench.(AP" until:2017-09-01', '"Chicago" "United States" until:2017-09-01', '"Chicago" "Ronald Reagan" until:2017-09-01', '"Chicago" "1981" until:2017-09-01', '"Chicago" "more than 3,300" until:2017-09-01', '"7th" "headquartered" until:2017-09-01', '"7th" "Posner" until:2017-09-01', '"7th" "U.S. Circuit Court of Appeals" until:2017-09-01', '"7th" "Illinois" until:2017-09-01', '"7th" "bench.(AP" until:2017-09-01', '"7th" "United States" until:2017-09-01', '"7th" "Ronald Reagan" until:2017-09-01', '"7th" "1981" until:2017-09-01', '"7th" "more than 3,300" until:2017-09-01', '"headquartered" "Posner" until:2017-09-01', '"headquartered" "U.S. Circuit Court of Appeals" until:2017-09-01', '"headquartered" "Illinois" until:2017-09-01', '"headquartered" "bench.(AP" until:2017-09-01', '"headquartered" "United States" until:2017-09-01', '"headquartered" "Ronald Reagan" until:2017-09-01', '"headquartered" "1981" until:2017-09-01', '"headquartered" "more than 3,300" until:2017-09-01', '"Posner" "U.S. Circuit Court of Appeals" until:2017-09-01', '"Posner" "Illinois" until:2017-09-01', '"Posner" "bench.(AP" until:2017-09-01', '"Posner" "United States" until:2017-09-01', '"Posner" "Ronald Reagan" until:2017-09-01', '"Posner" "1981" until:2017-09-01', '"Posner" "more than 3,300" until:2017-09-01', '"U.S. Circuit Court of Appeals" "Illinois" until:2017-09-01', '"U.S. Circuit  ...
# 56
#  ['"Bill English" "New Zealand" until:2017-09-01', '"Bill English" "polls" until:2017-09-01', '"Bill English" "the National Party" until:2017-09-01', '"Bill English" "surges" until:2017-09-01', '"Bill English" "The Labour Party" until:2017-09-01', '"Bill English" "led" until:2017-09-01', '"Bill English" "Jacinda Ardern" until:2017-09-01', '"New Zealand" "polls" until:2017-09-01', '"New Zealand" "the National Party" until:2017-09-01', '"New Zealand" "surges" until:2017-09-01', '"New Zealand" "The Labour Party" until:2017-09-01', '"New Zealand" "led" until:2017-09-01', '"New Zealand" "Jacinda Ardern" until:2017-09-01', '"polls" "the National Party" until:2017-09-01', '"polls" "surges" until:2017-09-01', '"polls" "The Labour Party" until:2017-09-01', '"polls" "led" until:2017-09-01', '"polls" "Jacinda Ardern" until:2017-09-01', '"the National Party" "surges" until:2017-09-01', '"the National Party" "The Labour Party" until:2017-09-01', '"the National Party" "led" until:2017-09-01', '"the National Party" "Jacinda Ardern" until:2017-09-01', '"surges" "The Labour Party" until:2017-09-01', '"surges" "led" until:2017-09-01', '"surges" "Jacinda Ardern" until:2017-09-01', '"The Labour Party" "led" until:2017-09-01', '"The Labour Party" "Jacinda Ardern" until:2017-09-01', '"led" "Jacinda Ardern" until:2017-09-01', '"Bill English" "New Zealand" until:2017-09-02', '"Bill English" "polls" until:2017-09-02', '"Bill English" "the National Party" until:2017-09-02', '"Bill English" "surges" until:2017-09-02', '"Bill English" "The Labour Party" until:2017-09-02', '"Bill English" "led" until:2017-09-02', '"Bill English" "Jacinda Ardern" until:2017-09-02', '"New Zealand" "polls" until:2017-09-02', '"New Zealand" "the National Party" until:2017-09-02', '"New Zealand" "surges" until:2017-09-02', '"New Zealand" "The Labour Party" until:2017-09-02', '"New Zealand" "led" until:2017-09-02', '"New Zealand" "Jacinda Ardern" until:2017-09-02', '"polls" "the National Party" until:2017-09-02', '"polls" "surges" until:2017-09-02', '"polls" "The Labour Party" until:2017-09-02', '"polls" "led" until:2017-09-02', '"polls" "Jacinda Ardern" until:2017-09-02', '"the National Party" "surges" until:2017-09-02', '"the National Party" "The Labour Party" until:2017-09-02', '"the National Party" "led" until:2017-09-02', '"the National Party" "Jacinda Ardern" until:2017-09-02', '"surges" "The Labour Party" until:2017-09-02', '"surges" "led" until:2017-09-02', '"surges" "Jacinda Ardern" until:2017-09-02', '"The Labour Party" "led" until:2017-09-02', '"The Labour Party" "Jacinda Ardern" until:2017-09-02', '"led" "Jacinda Ardern" until:2017-09-02']
# 42
#  ['"Kenya" "The Supreme Court" until:2017-09-01', '"Kenya" "election" until:2017-09-01', '"Kenya" "reelected" until:2017-09-01', '"Kenya" "indicated" until:2017-09-01', '"Kenya" "annuls" until:2017-09-01', '"Kenya" "Uhuru Kenyatta" until:2017-09-01', '"The Supreme Court" "election" until:2017-09-01', '"The Supreme Court" "reelected" until:2017-09-01', '"The Supreme Court" "indicated" until:2017-09-01', '"The Supreme Court" "annuls" until:2017-09-01', '"The Supreme Court" "Uhuru Kenyatta" until:2017-09-01', '"election" "reelected" until:2017-09-01', '"election" "indicated" until:2017-09-01', '"election" "annuls" until:2017-09-01', '"election" "Uhuru Kenyatta" until:2017-09-01', '"reelected" "indicated" until:2017-09-01', '"reelected" "annuls" until:2017-09-01', '"reelected" "Uhuru Kenyatta" until:2017-09-01', '"indicated" "annuls" until:2017-09-01', '"indicated" "Uhuru Kenyatta" until:2017-09-01', '"annuls" "Uhuru Kenyatta" until:2017-09-01', '"Kenya" "The Supreme Court" until:2017-09-02', '"Kenya" "election" until:2017-09-02', '"Kenya" "reelected" until:2017-09-02', '"Kenya" "indicated" until:2017-09-02', '"Kenya" "annuls" until:2017-09-02', '"Kenya" "Uhuru Kenyatta" until:2017-09-02', '"The Supreme Court" "election" until:2017-09-02', '"The Supreme Court" "reelected" until:2017-09-02', '"The Supreme Court" "indicated" until:2017-09-02', '"The Supreme Court" "annuls" until:2017-09-02', '"The Supreme Court" "Uhuru Kenyatta" until:2017-09-02', '"election" "reelected" until:2017-09-02', '"election" "indicated" until:2017-09-02', '"election" "annuls" until:2017-09-02', '"election" "Uhuru Kenyatta" until:2017-09-02', '"reelected" "indicated" until:2017-09-02', '"reelected" "annuls" until:2017-09-02', '"reelected" "Uhuru Kenyatta" until:2017-09-02', '"indicated" "annuls" until:2017-09-02', '"indicated" "Uhuru Kenyatta" until:2017-09-02', '"annuls" "Uhuru Kenyatta" until:2017-09-02']
# 90
#  ['"rescind" "the House of Representatives" until:2017-09-01', '"rescind" "entered" until:2017-09-01', '"rescind" "urges" until:2017-09-01', '"rescind" "Trump" until:2017-09-01', '"rescind" "U.S." until:2017-09-01', '"rescind" "Paul Ryan" until:2017-09-01', '"rescind" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"rescind" "DACA" until:2017-09-01', '"rescind" "Donald Trump" until:2017-09-01', '"the House of Representatives" "entered" until:2017-09-01', '"the House of Representatives" "urges" until:2017-09-01', '"the House of Representatives" "Trump" until:2017-09-01', '"the House of Representatives" "U.S." until:2017-09-01', '"the House of Representatives" "Paul Ryan" until:2017-09-01', '"the House of Representatives" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"the House of Representatives" "DACA" until:2017-09-01', '"the House of Representatives" "Donald Trump" until:2017-09-01', '"entered" "urges" until:2017-09-01', '"entered" "Trump" until:2017-09-01', '"entered" "U.S." until:2017-09-01', '"entered" "Paul Ryan" until:2017-09-01', '"entered" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"entered" "DACA" until:2017-09-01', '"entered" "Donald Trump" until:2017-09-01', '"urges" "Trump" until:2017-09-01', '"urges" "U.S." until:2017-09-01', '"urges" "Paul Ryan" until:2017-09-01', '"urges" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"urges" "DACA" until:2017-09-01', '"urges" "Donald Trump" until:2017-09-01', '"Trump" "U.S." until:2017-09-01', '"Trump" "Paul Ryan" until:2017-09-01', '"Trump" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"Trump" "DACA" until:2017-09-01', '"Trump" "Donald Trump" until:2017-09-01', '"U.S." "Paul Ryan" until:2017-09-01', '"U.S." "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"U.S." "DACA" until:2017-09-01', '"U.S." "Donald Trump" until:2017-09-01', '"Paul Ryan" "the Deferred Action for Childhood Arrivals" until:2017-09-01', '"Paul Ryan" "DACA" until:2017-09-01', '"Paul Ryan" "Donald Trump" until:2017-09-01', '"the Deferred Action for Childhood Arrivals" "DACA" until:2017-09-01', '"the Deferred Action for Childhood Arrivals" "Donald Trump" until:2017-09-01', '"DACA" "Donald Trump" until:2017-09-01', '"rescind" "the House of Representatives" until:2017-09-02', '"rescind" "entered" until:2017-09-02', '"rescind" "urges" until:2017-09-02', '"rescind" "Trump" until:2017-09-02', '"rescind" "U.S." until:2017-09-02', '"rescind" "Paul Ryan" until:2017-09-02', '"rescind" "the Deferred Action for Childhood Arrivals" until:2017-09-02', '"rescind" "DACA" until:2017-09-02', '"rescind" "Donald Trump" until:2017-09-02', '"the House of Representatives" "entered" until:2017-09-02', '"the House of Representatives" "urges" until:2017-09-02', '"the House of Representatives" "Trump" until:2017-09-02', '"the House of Representatives" "U.S." until:2017-09-02', '"the House of Representatives" "Paul Ryan" until:2017-09-02', '"the House of Representatives" "the Deferred Action for Childhood Arrivals" until:2017-09-02', '"the House of Representatives" "DACA" until:2017-09-02', '"the House of Representatives" "Donald Trump" until:2017-09-02', '"entered" "urges" until:2017-09-02', '"entered" "Trump" until:2017-09-02', '"entered" "U.S." until:2017-09-02', '"entered" "Paul Ryan" until:2017-09-02', '"entered" "the Deferred Action for Childhood Arrivals" until:2017-09-02', '"entered" "DACA" until:2017-09-02', '"entered" "Donald Trump" until:2017-09-02', '"urges" "Trump" until:2017-09-02', '"urges" "U.S." until:2017-09-02', '"urges" "Paul Ryan" until:2017-09-02', '"urges" "the Deferred Action for Childhood Arrivals" until:2017-09-02', '"urges" "DACA" until:2017-09-02', '"urges" "Donald Trump" until:2017-09-02', '"Trump" "U.S." until:2017-09-02', '"Trump" "Paul Ryan" until:2017-09-02', '"Trump" "the Deferred Action for Childhood Arrivals" until:2017-09-02', '"Trump" "DACA" until:2017-09-02', '"Trump" "Donald Trump" until:2 ...
# 90
#  ['"Moon" "planet" until:2017-09-01', '"Moon" "7 million km" until:2017-09-01', '"Moon" "4.4 kilometers" until:2017-09-01', '"Moon" "Asteroid 3122 Florence" until:2017-09-01', '"Moon" "roughly 2.7 miles" until:2017-09-01', '"Moon" "comes" until:2017-09-01', '"Moon" "4.4 million miles" until:2017-09-01', '"Moon" "Earth" until:2017-09-01', '"Moon" "18" until:2017-09-01', '"planet" "7 million km" until:2017-09-01', '"planet" "4.4 kilometers" until:2017-09-01', '"planet" "Asteroid 3122 Florence" until:2017-09-01', '"planet" "roughly 2.7 miles" until:2017-09-01', '"planet" "comes" until:2017-09-01', '"planet" "4.4 million miles" until:2017-09-01', '"planet" "Earth" until:2017-09-01', '"planet" "18" until:2017-09-01', '"7 million km" "4.4 kilometers" until:2017-09-01', '"7 million km" "Asteroid 3122 Florence" until:2017-09-01', '"7 million km" "roughly 2.7 miles" until:2017-09-01', '"7 million km" "comes" until:2017-09-01', '"7 million km" "4.4 million miles" until:2017-09-01', '"7 million km" "Earth" until:2017-09-01', '"7 million km" "18" until:2017-09-01', '"4.4 kilometers" "Asteroid 3122 Florence" until:2017-09-01', '"4.4 kilometers" "roughly 2.7 miles" until:2017-09-01', '"4.4 kilometers" "comes" until:2017-09-01', '"4.4 kilometers" "4.4 million miles" until:2017-09-01', '"4.4 kilometers" "Earth" until:2017-09-01', '"4.4 kilometers" "18" until:2017-09-01', '"Asteroid 3122 Florence" "roughly 2.7 miles" until:2017-09-01', '"Asteroid 3122 Florence" "comes" until:2017-09-01', '"Asteroid 3122 Florence" "4.4 million miles" until:2017-09-01', '"Asteroid 3122 Florence" "Earth" until:2017-09-01', '"Asteroid 3122 Florence" "18" until:2017-09-01', '"roughly 2.7 miles" "comes" until:2017-09-01', '"roughly 2.7 miles" "4.4 million miles" until:2017-09-01', '"roughly 2.7 miles" "Earth" until:2017-09-01', '"roughly 2.7 miles" "18" until:2017-09-01', '"comes" "4.4 million miles" until:2017-09-01', '"comes" "Earth" until:2017-09-01', '"comes" "18" until:2017-09-01', '"4.4 million miles" "Earth" until:2017-09-01', '"4.4 million miles" "18" until:2017-09-01', '"Earth" "18" until:2017-09-01', '"Moon" "planet" until:2017-09-02', '"Moon" "7 million km" until:2017-09-02', '"Moon" "4.4 kilometers" until:2017-09-02', '"Moon" "Asteroid 3122 Florence" until:2017-09-02', '"Moon" "roughly 2.7 miles" until:2017-09-02', '"Moon" "comes" until:2017-09-02', '"Moon" "4.4 million miles" until:2017-09-02', '"Moon" "Earth" until:2017-09-02', '"Moon" "18" until:2017-09-02', '"planet" "7 million km" until:2017-09-02', '"planet" "4.4 kilometers" until:2017-09-02', '"planet" "Asteroid 3122 Florence" until:2017-09-02', '"planet" "roughly 2.7 miles" until:2017-09-02', '"planet" "comes" until:2017-09-02', '"planet" "4.4 million miles" until:2017-09-02', '"planet" "Earth" until:2017-09-02', '"planet" "18" until:2017-09-02', '"7 million km" "4.4 kilometers" until:2017-09-02', '"7 million km" "Asteroid 3122 Florence" until:2017-09-02', '"7 million km" "roughly 2.7 miles" until:2017-09-02', '"7 million km" "comes" until:2017-09-02', '"7 million km" "4.4 million miles" until:2017-09-02', '"7 million km" "Earth" until:2017-09-02', '"7 million km" "18" until:2017-09-02', '"4.4 kilometers" "Asteroid 3122 Florence" until:2017-09-02', '"4.4 kilometers" "roughly 2.7 miles" until:2017-09-02', '"4.4 kilometers" "comes" until:2017-09-02', '"4.4 kilometers" "4.4 million miles" until:2017-09-02', '"4.4 kilometers" "Earth" until:2017-09-02', '"4.4 kilometers" "18" until:2017-09-02', '"Asteroid 3122 Florence" "roughly 2.7 miles" until:2017-09-02', '"Asteroid 3122 Florence" "comes" until:2017-09-02', '"Asteroid 3122 Florence" "4.4 million miles" until:2017-09-02', '"Asteroid 3122 Florence" "Earth" until:2017-09-02', '"Asteroid 3122 Florence" "18" until:2017-09-02', '"roughly 2.7 miles" "comes" until:2017-09-02', '"roughly 2.7 miles" "4.4 million miles" until:2017-09-02', '"roughly 2.7 miles" "Earth" until:2017-09-02', '"roughly 2.7 miles" "18" until:2017-09-02', '"comes" "4.4 million miles"  ...
# 90
#  ['"Seven" "Levant" until:2017-09-02', '"Seven" "claims" until:2017-09-02', '"Seven" "Samarra" until:2017-09-02', '"Seven" "attack" until:2017-09-02', '"Seven" "The Islamic State of" until:2017-09-02', '"Seven" "killed" until:2017-09-02', '"Seven" "Iraq" until:2017-09-02', '"Seven" "13" until:2017-09-02', '"Seven" "injured" until:2017-09-02', '"Levant" "claims" until:2017-09-02', '"Levant" "Samarra" until:2017-09-02', '"Levant" "attack" until:2017-09-02', '"Levant" "The Islamic State of" until:2017-09-02', '"Levant" "killed" until:2017-09-02', '"Levant" "Iraq" until:2017-09-02', '"Levant" "13" until:2017-09-02', '"Levant" "injured" until:2017-09-02', '"claims" "Samarra" until:2017-09-02', '"claims" "attack" until:2017-09-02', '"claims" "The Islamic State of" until:2017-09-02', '"claims" "killed" until:2017-09-02', '"claims" "Iraq" until:2017-09-02', '"claims" "13" until:2017-09-02', '"claims" "injured" until:2017-09-02', '"Samarra" "attack" until:2017-09-02', '"Samarra" "The Islamic State of" until:2017-09-02', '"Samarra" "killed" until:2017-09-02', '"Samarra" "Iraq" until:2017-09-02', '"Samarra" "13" until:2017-09-02', '"Samarra" "injured" until:2017-09-02', '"attack" "The Islamic State of" until:2017-09-02', '"attack" "killed" until:2017-09-02', '"attack" "Iraq" until:2017-09-02', '"attack" "13" until:2017-09-02', '"attack" "injured" until:2017-09-02', '"The Islamic State of" "killed" until:2017-09-02', '"The Islamic State of" "Iraq" until:2017-09-02', '"The Islamic State of" "13" until:2017-09-02', '"The Islamic State of" "injured" until:2017-09-02', '"killed" "Iraq" until:2017-09-02', '"killed" "13" until:2017-09-02', '"killed" "injured" until:2017-09-02', '"Iraq" "13" until:2017-09-02', '"Iraq" "injured" until:2017-09-02', '"13" "injured" until:2017-09-02', '"Seven" "Levant" until:2017-09-03', '"Seven" "claims" until:2017-09-03', '"Seven" "Samarra" until:2017-09-03', '"Seven" "attack" until:2017-09-03', '"Seven" "The Islamic State of" until:2017-09-03', '"Seven" "killed" until:2017-09-03', '"Seven" "Iraq" until:2017-09-03', '"Seven" "13" until:2017-09-03', '"Seven" "injured" until:2017-09-03', '"Levant" "claims" until:2017-09-03', '"Levant" "Samarra" until:2017-09-03', '"Levant" "attack" until:2017-09-03', '"Levant" "The Islamic State of" until:2017-09-03', '"Levant" "killed" until:2017-09-03', '"Levant" "Iraq" until:2017-09-03', '"Levant" "13" until:2017-09-03', '"Levant" "injured" until:2017-09-03', '"claims" "Samarra" until:2017-09-03', '"claims" "attack" until:2017-09-03', '"claims" "The Islamic State of" until:2017-09-03', '"claims" "killed" until:2017-09-03', '"claims" "Iraq" until:2017-09-03', '"claims" "13" until:2017-09-03', '"claims" "injured" until:2017-09-03', '"Samarra" "attack" until:2017-09-03', '"Samarra" "The Islamic State of" until:2017-09-03', '"Samarra" "killed" until:2017-09-03', '"Samarra" "Iraq" until:2017-09-03', '"Samarra" "13" until:2017-09-03', '"Samarra" "injured" until:2017-09-03', '"attack" "The Islamic State of" until:2017-09-03', '"attack" "killed" until:2017-09-03', '"attack" "Iraq" until:2017-09-03', '"attack" "13" until:2017-09-03', '"attack" "injured" until:2017-09-03', '"The Islamic State of" "killed" until:2017-09-03', '"The Islamic State of" "Iraq" until:2017-09-03', '"The Islamic State of" "13" until:2017-09-03', '"The Islamic State of" "injured" until:2017-09-03', '"killed" "Iraq" until:2017-09-03', '"killed" "13" until:2017-09-03', '"killed" "injured" until:2017-09-03', '"Iraq" "13" until:2017-09-03', '"Iraq" "injured" until:2017-09-03', '"13" "injured" until:2017-09-03']
# 90
#  ['"possess" "City" until:2017-09-02', '"possess" "FBI" until:2017-09-02', '"possess" "New York City" until:2017-09-02', '"possess" "earlier in March" until:2017-09-02', '"possess" "indicating" until:2017-09-02', '"possess" "wiretapped" until:2017-09-02', '"possess" "NSD" until:2017-09-02', '"possess" "Trump Tower" until:2017-09-02', '"possess" "New York" until:2017-09-02', '"City" "FBI" until:2017-09-02', '"City" "New York City" until:2017-09-02', '"City" "earlier in March" until:2017-09-02', '"City" "indicating" until:2017-09-02', '"City" "wiretapped" until:2017-09-02', '"City" "NSD" until:2017-09-02', '"City" "Trump Tower" until:2017-09-02', '"City" "New York" until:2017-09-02', '"FBI" "New York City" until:2017-09-02', '"FBI" "earlier in March" until:2017-09-02', '"FBI" "indicating" until:2017-09-02', '"FBI" "wiretapped" until:2017-09-02', '"FBI" "NSD" until:2017-09-02', '"FBI" "Trump Tower" until:2017-09-02', '"FBI" "New York" until:2017-09-02', '"New York City" "earlier in March" until:2017-09-02', '"New York City" "indicating" until:2017-09-02', '"New York City" "wiretapped" until:2017-09-02', '"New York City" "NSD" until:2017-09-02', '"New York City" "Trump Tower" until:2017-09-02', '"New York City" "New York" until:2017-09-02', '"earlier in March" "indicating" until:2017-09-02', '"earlier in March" "wiretapped" until:2017-09-02', '"earlier in March" "NSD" until:2017-09-02', '"earlier in March" "Trump Tower" until:2017-09-02', '"earlier in March" "New York" until:2017-09-02', '"indicating" "wiretapped" until:2017-09-02', '"indicating" "NSD" until:2017-09-02', '"indicating" "Trump Tower" until:2017-09-02', '"indicating" "New York" until:2017-09-02', '"wiretapped" "NSD" until:2017-09-02', '"wiretapped" "Trump Tower" until:2017-09-02', '"wiretapped" "New York" until:2017-09-02', '"NSD" "Trump Tower" until:2017-09-02', '"NSD" "New York" until:2017-09-02', '"Trump Tower" "New York" until:2017-09-02', '"possess" "City" until:2017-09-03', '"possess" "FBI" until:2017-09-03', '"possess" "New York City" until:2017-09-03', '"possess" "earlier in March" until:2017-09-03', '"possess" "indicating" until:2017-09-03', '"possess" "wiretapped" until:2017-09-03', '"possess" "NSD" until:2017-09-03', '"possess" "Trump Tower" until:2017-09-03', '"possess" "New York" until:2017-09-03', '"City" "FBI" until:2017-09-03', '"City" "New York City" until:2017-09-03', '"City" "earlier in March" until:2017-09-03', '"City" "indicating" until:2017-09-03', '"City" "wiretapped" until:2017-09-03', '"City" "NSD" until:2017-09-03', '"City" "Trump Tower" until:2017-09-03', '"City" "New York" until:2017-09-03', '"FBI" "New York City" until:2017-09-03', '"FBI" "earlier in March" until:2017-09-03', '"FBI" "indicating" until:2017-09-03', '"FBI" "wiretapped" until:2017-09-03', '"FBI" "NSD" until:2017-09-03', '"FBI" "Trump Tower" until:2017-09-03', '"FBI" "New York" until:2017-09-03', '"New York City" "earlier in March" until:2017-09-03', '"New York City" "indicating" until:2017-09-03', '"New York City" "wiretapped" until:2017-09-03', '"New York City" "NSD" until:2017-09-03', '"New York City" "Trump Tower" until:2017-09-03', '"New York City" "New York" until:2017-09-03', '"earlier in March" "indicating" until:2017-09-03', '"earlier in March" "wiretapped" until:2017-09-03', '"earlier in March" "NSD" until:2017-09-03', '"earlier in March" "Trump Tower" until:2017-09-03', '"earlier in March" "New York" until:2017-09-03', '"indicating" "wiretapped" until:2017-09-03', '"indicating" "NSD" until:2017-09-03', '"indicating" "Trump Tower" until:2017-09-03', '"indicating" "New York" until:2017-09-03', '"wiretapped" "NSD" until:2017-09-03', '"wiretapped" "Trump Tower" until:2017-09-03', '"wiretapped" "New York" until:2017-09-03', '"NSD" "Trump Tower" until:2017-09-03', '"NSD" "New York" until:2017-09-03', '"Trump Tower" "New York" until:2017-09-03']
# 56
#  ['"fire" "Kenya" until:2017-09-02', '"fire" "hospitalised" until:2017-09-02', '"fire" "Seven" until:2017-09-02', '"fire" "Nairobi" until:2017-09-02', '"fire" "ten" until:2017-09-02', '"fire" "the Moi Girls School" until:2017-09-02', '"fire" "killed" until:2017-09-02', '"Kenya" "hospitalised" until:2017-09-02', '"Kenya" "Seven" until:2017-09-02', '"Kenya" "Nairobi" until:2017-09-02', '"Kenya" "ten" until:2017-09-02', '"Kenya" "the Moi Girls School" until:2017-09-02', '"Kenya" "killed" until:2017-09-02', '"hospitalised" "Seven" until:2017-09-02', '"hospitalised" "Nairobi" until:2017-09-02', '"hospitalised" "ten" until:2017-09-02', '"hospitalised" "the Moi Girls School" until:2017-09-02', '"hospitalised" "killed" until:2017-09-02', '"Seven" "Nairobi" until:2017-09-02', '"Seven" "ten" until:2017-09-02', '"Seven" "the Moi Girls School" until:2017-09-02', '"Seven" "killed" until:2017-09-02', '"Nairobi" "ten" until:2017-09-02', '"Nairobi" "the Moi Girls School" until:2017-09-02', '"Nairobi" "killed" until:2017-09-02', '"ten" "the Moi Girls School" until:2017-09-02', '"ten" "killed" until:2017-09-02', '"the Moi Girls School" "killed" until:2017-09-02', '"fire" "Kenya" until:2017-09-03', '"fire" "hospitalised" until:2017-09-03', '"fire" "Seven" until:2017-09-03', '"fire" "Nairobi" until:2017-09-03', '"fire" "ten" until:2017-09-03', '"fire" "the Moi Girls School" until:2017-09-03', '"fire" "killed" until:2017-09-03', '"Kenya" "hospitalised" until:2017-09-03', '"Kenya" "Seven" until:2017-09-03', '"Kenya" "Nairobi" until:2017-09-03', '"Kenya" "ten" until:2017-09-03', '"Kenya" "the Moi Girls School" until:2017-09-03', '"Kenya" "killed" until:2017-09-03', '"hospitalised" "Seven" until:2017-09-03', '"hospitalised" "Nairobi" until:2017-09-03', '"hospitalised" "ten" until:2017-09-03', '"hospitalised" "the Moi Girls School" until:2017-09-03', '"hospitalised" "killed" until:2017-09-03', '"Seven" "Nairobi" until:2017-09-03', '"Seven" "ten" until:2017-09-03', '"Seven" "the Moi Girls School" until:2017-09-03', '"Seven" "killed" until:2017-09-03', '"Nairobi" "ten" until:2017-09-03', '"Nairobi" "the Moi Girls School" until:2017-09-03', '"Nairobi" "killed" until:2017-09-03', '"ten" "the Moi Girls School" until:2017-09-03', '"ten" "killed" until:2017-09-03', '"the Moi Girls School" "killed" until:2017-09-03']
# 30
#  ['"two" "East Timor" until:2017-09-02', '"two" "settle" until:2017-09-02', '"two" "countries" until:2017-09-02', '"two" "the Timor Sea" until:2017-09-02', '"two" "Australia" until:2017-09-02', '"East Timor" "settle" until:2017-09-02', '"East Timor" "countries" until:2017-09-02', '"East Timor" "the Timor Sea" until:2017-09-02', '"East Timor" "Australia" until:2017-09-02', '"settle" "countries" until:2017-09-02', '"settle" "the Timor Sea" until:2017-09-02', '"settle" "Australia" until:2017-09-02', '"countries" "the Timor Sea" until:2017-09-02', '"countries" "Australia" until:2017-09-02', '"the Timor Sea" "Australia" until:2017-09-02', '"two" "East Timor" until:2017-09-03', '"two" "settle" until:2017-09-03', '"two" "countries" until:2017-09-03', '"two" "the Timor Sea" until:2017-09-03', '"two" "Australia" until:2017-09-03', '"East Timor" "settle" until:2017-09-03', '"East Timor" "countries" until:2017-09-03', '"East Timor" "the Timor Sea" until:2017-09-03', '"East Timor" "Australia" until:2017-09-03', '"settle" "countries" until:2017-09-03', '"settle" "the Timor Sea" until:2017-09-03', '"settle" "Australia" until:2017-09-03', '"countries" "the Timor Sea" until:2017-09-03', '"countries" "Australia" until:2017-09-03', '"the Timor Sea" "Australia" until:2017-09-03']
# 20
#  ['"Kem Sokha" "alleged" until:2017-09-02', '"Kem Sokha" "arrested" until:2017-09-02', '"Kem Sokha" "Cambodian" until:2017-09-02', '"Kem Sokha" "treason" until:2017-09-02', '"alleged" "arrested" until:2017-09-02', '"alleged" "Cambodian" until:2017-09-02', '"alleged" "treason" until:2017-09-02', '"arrested" "Cambodian" until:2017-09-02', '"arrested" "treason" until:2017-09-02', '"Cambodian" "treason" until:2017-09-02', '"Kem Sokha" "alleged" until:2017-09-03', '"Kem Sokha" "arrested" until:2017-09-03', '"Kem Sokha" "Cambodian" until:2017-09-03', '"Kem Sokha" "treason" until:2017-09-03', '"alleged" "arrested" until:2017-09-03', '"alleged" "Cambodian" until:2017-09-03', '"alleged" "treason" until:2017-09-03', '"arrested" "Cambodian" until:2017-09-03', '"arrested" "treason" until:2017-09-03', '"Cambodian" "treason" until:2017-09-03']
# 56
#  ['"pay" "Cambodia" until:2017-09-03', '"pay" "companies" until:2017-09-03', '"pay" "USD$6.3 million" until:2017-09-03', '"pay" "operating" until:2017-09-03', '"pay" "initiated" until:2017-09-03', '"pay" "Hun Sen" until:2017-09-03', '"pay" "The Cambodia Daily newspaper" until:2017-09-03', '"Cambodia" "companies" until:2017-09-03', '"Cambodia" "USD$6.3 million" until:2017-09-03', '"Cambodia" "operating" until:2017-09-03', '"Cambodia" "initiated" until:2017-09-03', '"Cambodia" "Hun Sen" until:2017-09-03', '"Cambodia" "The Cambodia Daily newspaper" until:2017-09-03', '"companies" "USD$6.3 million" until:2017-09-03', '"companies" "operating" until:2017-09-03', '"companies" "initiated" until:2017-09-03', '"companies" "Hun Sen" until:2017-09-03', '"companies" "The Cambodia Daily newspaper" until:2017-09-03', '"USD$6.3 million" "operating" until:2017-09-03', '"USD$6.3 million" "initiated" until:2017-09-03', '"USD$6.3 million" "Hun Sen" until:2017-09-03', '"USD$6.3 million" "The Cambodia Daily newspaper" until:2017-09-03', '"operating" "initiated" until:2017-09-03', '"operating" "Hun Sen" until:2017-09-03', '"operating" "The Cambodia Daily newspaper" until:2017-09-03', '"initiated" "Hun Sen" until:2017-09-03', '"initiated" "The Cambodia Daily newspaper" until:2017-09-03', '"Hun Sen" "The Cambodia Daily newspaper" until:2017-09-03', '"pay" "Cambodia" until:2017-09-04', '"pay" "companies" until:2017-09-04', '"pay" "USD$6.3 million" until:2017-09-04', '"pay" "operating" until:2017-09-04', '"pay" "initiated" until:2017-09-04', '"pay" "Hun Sen" until:2017-09-04', '"pay" "The Cambodia Daily newspaper" until:2017-09-04', '"Cambodia" "companies" until:2017-09-04', '"Cambodia" "USD$6.3 million" until:2017-09-04', '"Cambodia" "operating" until:2017-09-04', '"Cambodia" "initiated" until:2017-09-04', '"Cambodia" "Hun Sen" until:2017-09-04', '"Cambodia" "The Cambodia Daily newspaper" until:2017-09-04', '"companies" "USD$6.3 million" until:2017-09-04', '"companies" "operating" until:2017-09-04', '"companies" "initiated" until:2017-09-04', '"companies" "Hun Sen" until:2017-09-04', '"companies" "The Cambodia Daily newspaper" until:2017-09-04', '"USD$6.3 million" "operating" until:2017-09-04', '"USD$6.3 million" "initiated" until:2017-09-04', '"USD$6.3 million" "Hun Sen" until:2017-09-04', '"USD$6.3 million" "The Cambodia Daily newspaper" until:2017-09-04', '"operating" "initiated" until:2017-09-04', '"operating" "Hun Sen" until:2017-09-04', '"operating" "The Cambodia Daily newspaper" until:2017-09-04', '"initiated" "Hun Sen" until:2017-09-04', '"initiated" "The Cambodia Daily newspaper" until:2017-09-04', '"Hun Sen" "The Cambodia Daily newspaper" until:2017-09-04']
# 110
#  ['"Hurricane Katrina\'s" "around $118 to $160 billion" until:2017-09-03', '"Hurricane Katrina\'s" "US$72 billion" until:2017-09-03', '"Hurricane Katrina\'s" "second" until:2017-09-03', '"Hurricane Katrina\'s" "Hurricane Harvey" until:2017-09-03', '"Hurricane Katrina\'s" "damage" until:2017-09-03', '"Hurricane Katrina\'s" "ranging" until:2017-09-03', '"Hurricane Katrina\'s" "projected" until:2017-09-03', '"Hurricane Katrina\'s" "estimated" until:2017-09-03', '"Hurricane Katrina\'s" "over $125 billion" until:2017-09-03', '"Hurricane Katrina\'s" "the United States\'s" until:2017-09-03', '"around $118 to $160 billion" "US$72 billion" until:2017-09-03', '"around $118 to $160 billion" "second" until:2017-09-03', '"around $118 to $160 billion" "Hurricane Harvey" until:2017-09-03', '"around $118 to $160 billion" "damage" until:2017-09-03', '"around $118 to $160 billion" "ranging" until:2017-09-03', '"around $118 to $160 billion" "projected" until:2017-09-03', '"around $118 to $160 billion" "estimated" until:2017-09-03', '"around $118 to $160 billion" "over $125 billion" until:2017-09-03', '"around $118 to $160 billion" "the United States\'s" until:2017-09-03', '"US$72 billion" "second" until:2017-09-03', '"US$72 billion" "Hurricane Harvey" until:2017-09-03', '"US$72 billion" "damage" until:2017-09-03', '"US$72 billion" "ranging" until:2017-09-03', '"US$72 billion" "projected" until:2017-09-03', '"US$72 billion" "estimated" until:2017-09-03', '"US$72 billion" "over $125 billion" until:2017-09-03', '"US$72 billion" "the United States\'s" until:2017-09-03', '"second" "Hurricane Harvey" until:2017-09-03', '"second" "damage" until:2017-09-03', '"second" "ranging" until:2017-09-03', '"second" "projected" until:2017-09-03', '"second" "estimated" until:2017-09-03', '"second" "over $125 billion" until:2017-09-03', '"second" "the United States\'s" until:2017-09-03', '"Hurricane Harvey" "damage" until:2017-09-03', '"Hurricane Harvey" "ranging" until:2017-09-03', '"Hurricane Harvey" "projected" until:2017-09-03', '"Hurricane Harvey" "estimated" until:2017-09-03', '"Hurricane Harvey" "over $125 billion" until:2017-09-03', '"Hurricane Harvey" "the United States\'s" until:2017-09-03', '"damage" "ranging" until:2017-09-03', '"damage" "projected" until:2017-09-03', '"damage" "estimated" until:2017-09-03', '"damage" "over $125 billion" until:2017-09-03', '"damage" "the United States\'s" until:2017-09-03', '"ranging" "projected" until:2017-09-03', '"ranging" "estimated" until:2017-09-03', '"ranging" "over $125 billion" until:2017-09-03', '"ranging" "the United States\'s" until:2017-09-03', '"projected" "estimated" until:2017-09-03', '"projected" "over $125 billion" until:2017-09-03', '"projected" "the United States\'s" until:2017-09-03', '"estimated" "over $125 billion" until:2017-09-03', '"estimated" "the United States\'s" until:2017-09-03', '"over $125 billion" "the United States\'s" until:2017-09-03', '"Hurricane Katrina\'s" "around $118 to $160 billion" until:2017-09-04', '"Hurricane Katrina\'s" "US$72 billion" until:2017-09-04', '"Hurricane Katrina\'s" "second" until:2017-09-04', '"Hurricane Katrina\'s" "Hurricane Harvey" until:2017-09-04', '"Hurricane Katrina\'s" "damage" until:2017-09-04', '"Hurricane Katrina\'s" "ranging" until:2017-09-04', '"Hurricane Katrina\'s" "projected" until:2017-09-04', '"Hurricane Katrina\'s" "estimated" until:2017-09-04', '"Hurricane Katrina\'s" "over $125 billion" until:2017-09-04', '"Hurricane Katrina\'s" "the United States\'s" until:2017-09-04', '"around $118 to $160 billion" "US$72 billion" until:2017-09-04', '"around $118 to $160 billion" "second" until:2017-09-04', '"around $118 to $160 billion" "Hurricane Harvey" until:2017-09-04', '"around $118 to $160 billion" "damage" until:2017-09-04', '"around $118 to $160 billion" "ranging" until:2017-09-04', '"around $118 to $160 billion" "projected" until:2017-09-04', '"around $118 to $160 billion" "estimated" until:2017-09-04', '"around $118 to $160 billion" "over $125 ...
# 72
# ...
# 12
#  ['"visit" "Narendra Modi" until:2017-09-05', '"visit" "Myanmar" until:2017-09-05', '"visit" "Indian" until:2017-09-05', '"Narendra Modi" "Myanmar" until:2017-09-05', '"Narendra Modi" "Indian" until:2017-09-05', '"Myanmar" "Indian" until:2017-09-05', '"visit" "Narendra Modi" until:2017-09-06', '"visit" "Myanmar" until:2017-09-06', '"visit" "Indian" until:2017-09-06', '"Narendra Modi" "Myanmar" until:2017-09-06', '"Narendra Modi" "Indian" until:2017-09-06', '"Myanmar" "Indian" until:2017-09-06']
# 156
#  ['"The Independent" "Japan" until:2017-09-05', '"The Independent" "Japan鈥揢nited States" until:2017-09-05', '"The Independent" "South Korea" until:2017-09-05', '"The Independent" "relations" until:2017-09-05', '"The Independent" "South Korea鈥揢nited States" until:2017-09-05', '"The Independent" "U.S." until:2017-09-05', '"The Independent" "the United States" until:2017-09-05', '"The Independent" "allowing" until:2017-09-05', '"The Independent" "\r\n\r\n" until:2017-09-05', '"The Independent" "announces" until:2017-09-05', '"The Independent" "increased" until:2017-09-05', '"The Independent" "Donald Trump" until:2017-09-05', '"Japan" "Japan鈥揢nited States" until:2017-09-05', '"Japan" "South Korea" until:2017-09-05', '"Japan" "relations" until:2017-09-05', '"Japan" "South Korea鈥揢nited States" until:2017-09-05', '"Japan" "U.S." until:2017-09-05', '"Japan" "the United States" until:2017-09-05', '"Japan" "allowing" until:2017-09-05', '"Japan" "\r\n\r\n" until:2017-09-05', '"Japan" "announces" until:2017-09-05', '"Japan" "increased" until:2017-09-05', '"Japan" "Donald Trump" until:2017-09-05', '"Japan鈥揢nited States" "South Korea" until:2017-09-05', '"Japan鈥揢nited States" "relations" until:2017-09-05', '"Japan鈥揢nited States" "South Korea鈥揢nited States" until:2017-09-05', '"Japan鈥揢nited States" "U.S." until:2017-09-05', '"Japan鈥揢nited States" "the United States" until:2017-09-05', '"Japan鈥揢nited States" "allowing" until:2017-09-05', '"Japan鈥揢nited States" "\r\n\r\n" until:2017-09-05', '"Japan鈥揢nited States" "announces" until:2017-09-05', '"Japan鈥揢nited States" "increased" until:2017-09-05', '"Japan鈥揢nited States" "Donald Trump" until:2017-09-05', '"South Korea" "relations" until:2017-09-05', '"South Korea" "South Korea鈥揢nited States" until:2017-09-05', '"South Korea" "U.S." until:2017-09-05', '"South Korea" "the United States" until:2017-09-05', '"South Korea" "allowing" until:2017-09-05', '"South Korea" "\r\n\r\n" until:2017-09-05', '"South Korea" "announces" until:2017-09-05', '"South Korea" "increased" until:2017-09-05', '"South Korea" "Donald Trump" until:2017-09-05', '"relations" "South Korea鈥揢nited States" until:2017-09-05', '"relations" "U.S." until:2017-09-05', '"relations" "the United States" until:2017-09-05', '"relations" "allowing" until:2017-09-05', '"relations" "\r\n\r\n" until:2017-09-05', '"relations" "announces" until:2017-09-05', '"relations" "increased" until:2017-09-05', '"relations" "Donald Trump" until:2017-09-05', '"South Korea鈥揢nited States" "U.S." until:2017-09-05', '"South Korea鈥揢nited States" "the United States" until:2017-09-05', '"South Korea鈥揢nited States" "allowing" until:2017-09-05', '"South Korea鈥揢nited States" "\r\n\r\n" until:2017-09-05', '"South Korea鈥揢nited States" "announces" until:2017-09-05', '"South Korea鈥揢nited States" "increased" until:2017-09-05', '"South Korea鈥揢nited States" "Donald Trump" until:2017-09-05', '"U.S." "the United States" until:2017-09-05', '"U.S." "allowing" until:2017-09-05', '"U.S." "\r\n\r\n" until:2017-09-05', '"U.S." "announces" until:2017-09-05', '"U.S." "increased" until:2017-09-05', '"U.S." "Donald Trump" until:2017-09-05', '"the United States" "allowing" until:2017-09-05', '"the United States" "\r\n\r\n" until:2017-09-05', '"the United States" "announces" until:2017-09-05', '"the United States" "increased" until:2017-09-05', '"the United States" "Donald Trump" until:2017-09-05', '"allowing" "\r\n\r\n" until:2017-09-05', '"allowing" "announces" until:2017-09-05', '"allowing" "increased" until:2017-09-05', '"allowing" "Donald Trump" until:2017-09-05', '"\r\n\r\n" "announces" until:2017-09-05', '"\r\n\r\n" "increased" until:2017-09-05', '"\r\n\r\n" "Donald Trump" until:2017-09-05', '"announces" "increased" until:2017-09-05', '"announces" "Donald Trump" until:2017-09-05', '"increased" "Donald Trump" until:2017-09-05', '"The Independent" "Japan" until:2017-09-06', '"The Independent" "Japan鈥揢nited States" until:2017-09-06', '"The Independent" "South Korea" until:2017-09-06',  ...
# 30
#  ['"city" "Lankesh Patrike" until:2017-09-05', '"city" "shot" until:2017-09-05', '"city" "Indian" until:2017-09-05', '"city" "Gauri Lankesh" until:2017-09-05', '"city" "Bengaluru" until:2017-09-05', '"Lankesh Patrike" "shot" until:2017-09-05', '"Lankesh Patrike" "Indian" until:2017-09-05', '"Lankesh Patrike" "Gauri Lankesh" until:2017-09-05', '"Lankesh Patrike" "Bengaluru" until:2017-09-05', '"shot" "Indian" until:2017-09-05', '"shot" "Gauri Lankesh" until:2017-09-05', '"shot" "Bengaluru" until:2017-09-05', '"Indian" "Gauri Lankesh" until:2017-09-05', '"Indian" "Bengaluru" until:2017-09-05', '"Gauri Lankesh" "Bengaluru" until:2017-09-05', '"city" "Lankesh Patrike" until:2017-09-06', '"city" "shot" until:2017-09-06', '"city" "Indian" until:2017-09-06', '"city" "Gauri Lankesh" until:2017-09-06', '"city" "Bengaluru" until:2017-09-06', '"Lankesh Patrike" "shot" until:2017-09-06', '"Lankesh Patrike" "Indian" until:2017-09-06', '"Lankesh Patrike" "Gauri Lankesh" until:2017-09-06', '"Lankesh Patrike" "Bengaluru" until:2017-09-06', '"shot" "Indian" until:2017-09-06', '"shot" "Gauri Lankesh" until:2017-09-06', '"shot" "Bengaluru" until:2017-09-06', '"Indian" "Gauri Lankesh" until:2017-09-06', '"Indian" "Bengaluru" until:2017-09-06', '"Gauri Lankesh" "Bengaluru" until:2017-09-06']
# 30
#  ['"Survey" "(The Guardian)" until:2017-09-05', '"Survey" "Australian" until:2017-09-05', '"Survey" "The High Court of Australia" until:2017-09-05', '"Survey" "citing" until:2017-09-05', '"Survey" "receives" until:2017-09-05', '"(The Guardian)" "Australian" until:2017-09-05', '"(The Guardian)" "The High Court of Australia" until:2017-09-05', '"(The Guardian)" "citing" until:2017-09-05', '"(The Guardian)" "receives" until:2017-09-05', '"Australian" "The High Court of Australia" until:2017-09-05', '"Australian" "citing" until:2017-09-05', '"Australian" "receives" until:2017-09-05', '"The High Court of Australia" "citing" until:2017-09-05', '"The High Court of Australia" "receives" until:2017-09-05', '"citing" "receives" until:2017-09-05', '"Survey" "(The Guardian)" until:2017-09-06', '"Survey" "Australian" until:2017-09-06', '"Survey" "The High Court of Australia" until:2017-09-06', '"Survey" "citing" until:2017-09-06', '"Survey" "receives" until:2017-09-06', '"(The Guardian)" "Australian" until:2017-09-06', '"(The Guardian)" "The High Court of Australia" until:2017-09-06', '"(The Guardian)" "citing" until:2017-09-06', '"(The Guardian)" "receives" until:2017-09-06', '"Australian" "The High Court of Australia" until:2017-09-06', '"Australian" "citing" until:2017-09-06', '"Australian" "receives" until:2017-09-06', '"The High Court of Australia" "citing" until:2017-09-06', '"The High Court of Australia" "receives" until:2017-09-06', '"citing" "receives" until:2017-09-06']
# 30
#  ['"Tsai Ing-wen" "the Republic of China" until:2017-09-05', '"Tsai Ing-wen" "Republic" until:2017-09-05', '"Tsai Ing-wen" "William Lai Ching-te" until:2017-09-05', '"Tsai Ing-wen" "Tainan" until:2017-09-05', '"Tsai Ing-wen" "appointed" until:2017-09-05', '"the Republic of China" "Republic" until:2017-09-05', '"the Republic of China" "William Lai Ching-te" until:2017-09-05', '"the Republic of China" "Tainan" until:2017-09-05', '"the Republic of China" "appointed" until:2017-09-05', '"Republic" "William Lai Ching-te" until:2017-09-05', '"Republic" "Tainan" until:2017-09-05', '"Republic" "appointed" until:2017-09-05', '"William Lai Ching-te" "Tainan" until:2017-09-05', '"William Lai Ching-te" "appointed" until:2017-09-05', '"Tainan" "appointed" until:2017-09-05', '"Tsai Ing-wen" "the Republic of China" until:2017-09-06', '"Tsai Ing-wen" "Republic" until:2017-09-06', '"Tsai Ing-wen" "William Lai Ching-te" until:2017-09-06', '"Tsai Ing-wen" "Tainan" until:2017-09-06', '"Tsai Ing-wen" "appointed" until:2017-09-06', '"the Republic of China" "Republic" until:2017-09-06', '"the Republic of China" "William Lai Ching-te" until:2017-09-06', '"the Republic of China" "Tainan" until:2017-09-06', '"the Republic of China" "appointed" until:2017-09-06', '"Republic" "William Lai Ching-te" until:2017-09-06', '"Republic" "Tainan" until:2017-09-06', '"Republic" "appointed" until:2017-09-06', '"William Lai Ching-te" "Tainan" until:2017-09-06', '"William Lai Ching-te" "appointed" until:2017-09-06', '"Tainan" "appointed" until:2017-09-06']
# 90
#  ['"about 800,000" "The Trump Administration" until:2017-09-05', '"about 800,000" "brought" until:2017-09-05', '"about 800,000" "the next six months" until:2017-09-05', '"about 800,000" "Congress" until:2017-09-05', '"about 800,000" "ending" until:2017-09-05', '"about 800,000" "U.S." until:2017-09-05', '"about 800,000" "DACA" until:2017-09-05', '"about 800,000" "halted" until:2017-09-05', '"about 800,000" "Administration" until:2017-09-05', '"The Trump Administration" "brought" until:2017-09-05', '"The Trump Administration" "the next six months" until:2017-09-05', '"The Trump Administration" "Congress" until:2017-09-05', '"The Trump Administration" "ending" until:2017-09-05', '"The Trump Administration" "U.S." until:2017-09-05', '"The Trump Administration" "DACA" until:2017-09-05', '"The Trump Administration" "halted" until:2017-09-05', '"The Trump Administration" "Administration" until:2017-09-05', '"brought" "the next six months" until:2017-09-05', '"brought" "Congress" until:2017-09-05', '"brought" "ending" until:2017-09-05', '"brought" "U.S." until:2017-09-05', '"brought" "DACA" until:2017-09-05', '"brought" "halted" until:2017-09-05', '"brought" "Administration" until:2017-09-05', '"the next six months" "Congress" until:2017-09-05', '"the next six months" "ending" until:2017-09-05', '"the next six months" "U.S." until:2017-09-05', '"the next six months" "DACA" until:2017-09-05', '"the next six months" "halted" until:2017-09-05', '"the next six months" "Administration" until:2017-09-05', '"Congress" "ending" until:2017-09-05', '"Congress" "U.S." until:2017-09-05', '"Congress" "DACA" until:2017-09-05', '"Congress" "halted" until:2017-09-05', '"Congress" "Administration" until:2017-09-05', '"ending" "U.S." until:2017-09-05', '"ending" "DACA" until:2017-09-05', '"ending" "halted" until:2017-09-05', '"ending" "Administration" until:2017-09-05', '"U.S." "DACA" until:2017-09-05', '"U.S." "halted" until:2017-09-05', '"U.S." "Administration" until:2017-09-05', '"DACA" "halted" until:2017-09-05', '"DACA" "Administration" until:2017-09-05', '"halted" "Administration" until:2017-09-05', '"about 800,000" "The Trump Administration" until:2017-09-06', '"about 800,000" "brought" until:2017-09-06', '"about 800,000" "the next six months" until:2017-09-06', '"about 800,000" "Congress" until:2017-09-06', '"about 800,000" "ending" until:2017-09-06', '"about 800,000" "U.S." until:2017-09-06', '"about 800,000" "DACA" until:2017-09-06', '"about 800,000" "halted" until:2017-09-06', '"about 800,000" "Administration" until:2017-09-06', '"The Trump Administration" "brought" until:2017-09-06', '"The Trump Administration" "the next six months" until:2017-09-06', '"The Trump Administration" "Congress" until:2017-09-06', '"The Trump Administration" "ending" until:2017-09-06', '"The Trump Administration" "U.S." until:2017-09-06', '"The Trump Administration" "DACA" until:2017-09-06', '"The Trump Administration" "halted" until:2017-09-06', '"The Trump Administration" "Administration" until:2017-09-06', '"brought" "the next six months" until:2017-09-06', '"brought" "Congress" until:2017-09-06', '"brought" "ending" until:2017-09-06', '"brought" "U.S." until:2017-09-06', '"brought" "DACA" until:2017-09-06', '"brought" "halted" until:2017-09-06', '"brought" "Administration" until:2017-09-06', '"the next six months" "Congress" until:2017-09-06', '"the next six months" "ending" until:2017-09-06', '"the next six months" "U.S." until:2017-09-06', '"the next six months" "DACA" until:2017-09-06', '"the next six months" "halted" until:2017-09-06', '"the next six months" "Administration" until:2017-09-06', '"Congress" "ending" until:2017-09-06', '"Congress" "U.S." until:2017-09-06', '"Congress" "DACA" until:2017-09-06', '"Congress" "halted" until:2017-09-06', '"Congress" "Administration" until:2017-09-06', '"ending" "U.S." until:2017-09-06', '"ending" "DACA" until:2017-09-06', '"ending" "halted" until:2017-09-06', '"ending" "Administration" until:2017-09-06', '"U.S."  ...
# 20
#  ['"US$2.2 billion" "Houston Rockets NBA" until:2017-09-05', '"US$2.2 billion" "Tilman Fertitta" until:2017-09-05', '"US$2.2 billion" "buys" until:2017-09-05', '"US$2.2 billion" "team" until:2017-09-05', '"Houston Rockets NBA" "Tilman Fertitta" until:2017-09-05', '"Houston Rockets NBA" "buys" until:2017-09-05', '"Houston Rockets NBA" "team" until:2017-09-05', '"Tilman Fertitta" "buys" until:2017-09-05', '"Tilman Fertitta" "team" until:2017-09-05', '"buys" "team" until:2017-09-05', '"US$2.2 billion" "Houston Rockets NBA" until:2017-09-06', '"US$2.2 billion" "Tilman Fertitta" until:2017-09-06', '"US$2.2 billion" "buys" until:2017-09-06', '"US$2.2 billion" "team" until:2017-09-06', '"Houston Rockets NBA" "Tilman Fertitta" until:2017-09-06', '"Houston Rockets NBA" "buys" until:2017-09-06', '"Houston Rockets NBA" "team" until:2017-09-06', '"Tilman Fertitta" "buys" until:2017-09-06', '"Tilman Fertitta" "team" until:2017-09-06', '"buys" "team" until:2017-09-06']
